# %%
import pandas as pd 
import matplotlib.pyplot as plt

data = pd.read_csv("out_tor_stats.csv") 


data.set_index('time', inplace=True)
#data.groupby('host')['bytes_written', 'bytes_read'].plot(legend=True)
#plt.show()

data.groupby('host')['bytes_written', 'bytes_read'].plot(legend=True)
plt.show()

#data.groupby('host')['bytes_read'].plot(legend=True)
#plt.show()

#data.plot.bar()
#plt.show()
