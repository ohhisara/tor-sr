# %%
import pandas as pd 
import matplotlib.pyplot as plt

path = ''

cl1 = pd.read_csv(path + "torhiddenclient1.csv").sort_values(by=['time']).iloc[900:1500] 
cl2 = pd.read_csv(path + "torhiddenclient2.csv").sort_values(by=['time']).iloc[900:1500] 
m1 = pd.read_csv(path + "middle1.csv").sort_values(by=['time']).iloc[800:1500]
m2 = pd.read_csv(path + "middle2.csv").sort_values(by=['time']).iloc[800:1500]
m3 = pd.read_csv(path + "middle3.csv").sort_values(by=['time']).iloc[800:1500]
m4 = pd.read_csv(path + "middle4.csv").sort_values(by=['time']).iloc[800:1500]
g1 = pd.read_csv(path + "guard1.csv").sort_values(by=['time']).iloc[800:1500]
g2 = pd.read_csv(path + "guard2.csv").sort_values(by=['time']).iloc[800:1500]
hs = pd.read_csv(path + "hiddenserver.csv").sort_values(by=['time']).iloc[900:1500]
exit = pd.read_csv(path + "exit.csv").sort_values(by=['time']).iloc[800:1500]

#e2 = pd.read_csv("exit2.csv").sort_values(by=['time']).iloc[800:1500]
#tc =  pd.read_csv("torclient.csv").sort_values(by=['time']).iloc[800:1500]
#tr1 =  pd.read_csv("relay1.csv").sort_values(by=['time']).iloc[800:1500]
#tr2 =  pd.read_csv("relay2.csv").sort_values(by=['time']).iloc[800:1500]
#hsdir = hs.orderby('time')

#hs = hs.   sort_values(by=['time'])

plt.figure(figsize=(30,10))
#plt.plot(cl1['time'],cl1['bytes_read'],label=True)
plt.plot(cl2['time'],cl2['bytes_read'],label=True)
#plt.plot(g2['time'],g2['bytes_written'],label=True)
plt.plot(hs['time'],hs['bytes_written'],label=True)

#plt.plot(tr1['time'],tr1['bytes_read'],label=True)
#plt.plot( tr2['time'], tr2['bytes_read'],label=True)
#plt.plot( e1['time'], e1['bytes_read'],label=True)
#plt.plot( e2['time'], e2['bytes_read'],label=True)

#df = pd.read_csv("stats.csv").groupby('host').apply(lambda x: x.sort_values(["time"], ascending = True)).reset_index(drop=True)

#print(df.head(50))

plt.plot()
plt.ylabel("Bytes")
plt.xlabel("Seconds")
plt.savefig('foo.png')
plt.show()
#print(hs.sort_values(by=['time'])['time'])
